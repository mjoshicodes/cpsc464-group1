# %% [markdown]
# ### This notebook demonstrates the ability of the DisparateImpactRemover algorithm.
# The algorithm corrects for imbalanced selection rates between unprivileged and privileged groups at various levels of repair. It follows the guidelines set forth by [1] for training the algorithm and classifier and uses the AdultDataset as an example.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

from matplotlib import pyplot as plt

import sys
sys.path.append("../")
import warnings

import numpy as np
# from tqdm import tqdm

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC as SVM
from sklearn.preprocessing import MinMaxScaler

from aif360.algorithms.preprocessing import DisparateImpactRemover
from aif360.datasets import AdultDataset
from aif360.metrics import BinaryLabelDatasetMetric
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'fairlearn': ExponentiatedGradientReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'
# WARNING:root:No module named 'fairlearn': GridSearchReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 19
#      16 from sklearn.svm import SVC as SVM
#      17 from sklearn.preprocessing import MinMaxScaler
# ---> 19 from aif360.algorithms.preprocessing import DisparateImpactRemover
#      20 from aif360.datasets import AdultDataset
#      21 from aif360.metrics import BinaryLabelDatasetMetric
#
# File ~/Desktop/AIF360/examples/../aif360/algorithms/preprocessing/__init__.py:4
#       2 from aif360.algorithms.preprocessing.lfr import LFR
#       3 from aif360.algorithms.preprocessing.optim_preproc import OptimPreproc
# ----> 4 from aif360.algorithms.preprocessing.reweighing import Reweighing
#
# File ~/Desktop/AIF360/examples/../aif360/algorithms/preprocessing/reweighing.py:4
#       1 import numpy as np
#       3 from aif360.algorithms import Transformer
# ----> 4 from aif360.metrics import utils
#       7 class Reweighing(Transformer):
#       8     """Reweighing is a preprocessing technique that Weights the examples in each
#       9     (group, label) combination differently to ensure fairness before
#      10     classification [4]_.
#    (...)
#      15            Systems, 2012.
#      16     """
#
# File ~/Desktop/AIF360/examples/../aif360/metrics/__init__.py:3
#       1 from aif360.metrics.metric import Metric
#       2 from aif360.metrics.dataset_metric import DatasetMetric
# ----> 3 from aif360.metrics.binary_label_dataset_metric import BinaryLabelDatasetMetric
#       4 from aif360.metrics.classification_metric import ClassificationMetric
#       5 from aif360.metrics.sample_distortion_metric import SampleDistortionMetric
#
# File ~/Desktop/AIF360/examples/../aif360/metrics/binary_label_dataset_metric.py:3
#       1 import numpy as np
#       2 from sklearn.neighbors import NearestNeighbors
# ----> 3 from aif360.algorithms.inprocessing.gerryfair.auditor import Auditor
#       4 from aif360.datasets import BinaryLabelDataset
#       5 from aif360.datasets.multiclass_label_dataset import MulticlassLabelDataset
#
# File ~/Desktop/AIF360/examples/../aif360/algorithms/inprocessing/__init__.py:6
#       4 from aif360.algorithms.inprocessing.meta_fair_classifier import MetaFairClassifier
#       5 from aif360.algorithms.inprocessing.gerryfair_classifier import GerryFairClassifier
# ----> 6 from aif360.algorithms.inprocessing.exponentiated_gradient_reduction import ExponentiatedGradientReduction
#       7 from aif360.algorithms.inprocessing.grid_search_reduction import GridSearchReduction
#
# File ~/Desktop/AIF360/examples/../aif360/algorithms/inprocessing/exponentiated_gradient_reduction.py:12
#       9 import pandas as pd
#      11 from aif360.algorithms import Transformer
# ---> 12 from aif360.sklearn.inprocessing import ExponentiatedGradientReduction as skExpGradRed
#      15 class ExponentiatedGradientReduction(Transformer):
#      16     """Exponentiated gradient reduction for fair classification.
#      17
#      18     Exponentiated gradient reduction is an in-processing technique that reduces
#    (...)
#      27            <https://arxiv.org/abs/1803.02453>`_
#      28     """
#
# File ~/Desktop/AIF360/examples/../aif360/sklearn/inprocessing/__init__.py:7
#       5 from aif360.sklearn.inprocessing.exponentiated_gradient_reduction import ExponentiatedGradientReduction
#       6 from aif360.sklearn.inprocessing.grid_search_reduction import GridSearchReduction
# ----> 7 from aif360.sklearn.inprocessing.infairness import SenSeI, SenSR
#       9 __all__ = [
#      10     'AdversarialDebiasing',
#      11     'ExponentiatedGradientReduction',
#      12     'GridSearchReduction',
#      13     'SenSeI', 'SenSR',
#      14 ]
#
# File ~/Desktop/AIF360/examples/../aif360/sklearn/inprocessing/infairness.py:1
# ----> 1 from inFairness import fairalgo
#       2 from sklearn.preprocessing import LabelBinarizer
#       3 from sklearn.utils.multiclass import type_of_target
#
# ModuleNotFoundError: No module named 'inFairness'

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC as SVM
from sklearn.preprocessing import MinMaxScaler

from aif360.algorithms.preprocessing import DisparateImpactRemover
from aif360.datasets import AdultDataset
from aif360.metrics import BinaryLabelDatasetMetric

# %%
protected = 'sex'
ad = AdultDataset(protected_attribute_names=[protected],
    privileged_classes=[['Male']], categorical_features=[],
    features_to_keep=['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week'])

# %%
scaler = MinMaxScaler(copy=False)

# %%
test, train = ad.split([16281])
train.features = scaler.fit_transform(train.features)
test.features = scaler.fit_transform(test.features)

index = train.feature_names.index(protected)

# %%
from tqdm import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 from tqdm import tqdm
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
DIs = []
for level in tqdm(np.linspace(0., 1., 11)):
    di = DisparateImpactRemover(repair_level=level)
    train_repd = di.fit_transform(train)
    test_repd = di.fit_transform(test)
    
    X_tr = np.delete(train_repd.features, index, axis=1)
    X_te = np.delete(test_repd.features, index, axis=1)
    y_tr = train_repd.labels.ravel()
    
    lmod = LogisticRegression(class_weight='balanced', solver='liblinear')
    lmod.fit(X_tr, y_tr)
    
    test_repd_pred = test_repd.copy()
    test_repd_pred.labels = lmod.predict(X_te)

    p = [{protected: 1}]
    u = [{protected: 0}]
    cm = BinaryLabelDatasetMetric(test_repd_pred, privileged_groups=p, unprivileged_groups=u)
    DIs.append(cm.disparate_impact())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [10], line 2
#       1 DIs = []
# ----> 2 for level in tqdm(np.linspace(0., 1., 11)):
#       3     di = DisparateImpactRemover(repair_level=level)
#       4     train_repd = di.fit_transform(train)
#
# NameError: name 'tqdm' is not defined

# %%
# %matplotlib notebook

plt.plot(np.linspace(0, 1, 11), DIs, marker='o')
plt.plot([0, 1], [1, 1], 'g')
plt.plot([0, 1], [0.8, 0.8], 'r')
plt.ylim([0.4, 1.2])
plt.ylabel('Disparate Impact (DI)')
plt.xlabel('repair level')
plt.show()
# Out:
# <div id='16ce9887-7759-46b8-8d77-fd7c25e0ed38'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [12], line 3
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
# ----> 3 plt.plot(np.linspace(0, 1, 11), DIs, marker='o')
#       4 plt.plot([0, 1], [1, 1], 'g')
#       5 plt.plot([0, 1], [0.8, 0.8], 'r')
#
# File ~/Library/Python/3.8/lib/python/site-packages/matplotlib/pyplot.py:2730, in plot(scalex, scaley, data, *args, **kwargs)
#    2728 @_copy_docstring_and_deprecators(Axes.plot)
#    2729 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2730     return gca().plot(
#    2731         *args, scalex=scalex, scaley=scaley,
#    2732         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/Library/Python/3.8/lib/python/site-packages/matplotlib/axes/_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File ~/Library/Python/3.8/lib/python/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/Library/Python/3.8/lib/python/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (11,) and (0,)

# %% [markdown]
#     References:
#         .. [1] M. Feldman, S. A. Friedler, J. Moeller, C. Scheidegger, and
#            S. Venkatasubramanian, "Certifying and removing disparate impact."
#            ACM SIGKDD International Conference on Knowledge Discovery and Data
#            Mining, 2015.
